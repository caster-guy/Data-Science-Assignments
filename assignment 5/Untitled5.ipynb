# %%
def table():
    print(f'''
      |     |     
   {m[0]}  |  {m[1]}  |  {m[2]}  
 _____|_____|_____
      |     |     
   {m[3]}  |  {m[4]}  |  {m[5]}  
 _____|_____|_____
      |     |     
   {m[6]}  |  {m[7]}  |  {m[8]}  
      |     |     
''')

# %%
# mode *(1)*
# human vs human ... almost final 
m = [1,2,3,4,5,6,7,8,9]
table()
wrong = True

_1st_symbol = input("choose the 1st player symbol  ")
_2st_symbol = input("choose the 2st player symbol  ")

for i in range(9):
    
        
    while True :     
        _1st_player = int(input("choose the 1st player index  "))
        if _1st_player == m[_1st_player-1] :
            m[_1st_player-1] = _1st_symbol
            table()
            break
        else :
            print("wrong index please try again")
            table()  
            
    check = False
    for k in range(7):
        if k % 3 == 0 and m[k] == m[k+1] == m [k+2] :
            print("winner")
            check = True
            break
        elif k in range(3) and m[k]==m[k+3]==m[k+6] :
            print("winner")
            check = True
            break
        elif k==0 and m[k]==m[k+4]==m[k+8] :
            print("winner")
            check = True
            break
        elif k==3 and m[k]==m[k+2]==m[k+4] :
            print("winner")
            check = True
            break
    if check :
        break 
    

    while True :     
        _2st_player = int(input("choose the 2st player index  "))
        if _2st_player == m[_2st_player-1] :
            m[_2st_player-1] = _2st_symbol
            table()
            break
        else :
            print("wrong index please try again")
            table()          
                
    
    check = False
    for k in range(7):
        if k % 3 == 0 and m[k] == m[k+1] == m [k+2] :
            print("winner")
            check = True
            break
        elif k in range(3) and m[k]==m[k+3]==m[k+6] :
            print("winner")
            check = True
            break
        elif k==0 and m[k]==m[k+4]==m[k+8] :
            print("winner")
            check = True
            break
        elif k==3 and m[k]==m[k+2]==m[k+4] :
            print("winner")
            check = True
            break
    if check :
        break
    
table()
# Out:
#       |     |
#    1  |  2  |  3
#  _____|_____|_____
#       |     |
#    4  |  5  |  6
#  _____|_____|_____
#       |     |
#    7  |  8  |  9
#       |     |
#
# choose the 1st player symbol  x
# choose the 2st player symbol  o
# choose the 1st player index  1
#
#       |     |
#    x  |  2  |  3
#  _____|_____|_____
#       |     |
#    4  |  5  |  6
#  _____|_____|_____
#       |     |
#    7  |  8  |  9
#       |     |
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e6a338132b66> in <module>
#      23     checker()
#      24
# ---> 25     if hell :
#      26         break
#      27
#
# NameError: name 'hell' is not defined

# %%
# mode *(2)*
# human vs pc ... almost
import random
m = list(range(1,10))
n = list(range(1,10))
y = "x"
table()
for i in range(5):
    wrong = True
    check = False
    while True :
        x = int(input("choose your index  "))
        if x == m[x-1] :
            m[x-1] = y
            break
        else :
            print("wrong index please try again")
            wrong = False
            table() 
            
    if i < 4 :
        while True :
            j = random.choice(n)
            if n[j-1] == m[j-1] :
                m[j-1] = "o"
                break
                
    for k in range(7):
        if k % 3 == 0 and m[k] == m[k+1] == m [k+2] :
            print("winner")
            check = True
            break
        elif k in range(3) and m[k]==m[k+3]==m[k+6] :
            print("winner")
            check = True
            break
        elif k==0 and m[k]==m[k+4]==m[k+8] :
            print("winner")
            check = True
            break
        elif k==3 and m[k]==m[k+2]==m[k+4] :
            print("winner")
            check = True
            break
    if check :
        break
        
    table()
# Out:
# choose your symbol  x
#
#       |     |
#    1  |  2  |  3
#  _____|_____|_____
#       |     |
#    4  |  5  |  6
#  _____|_____|_____
#       |     |
#    7  |  8  |  9
#       |     |
#
# choose your index  1
#
#       |     |
#    x  |  2  |  o
#  _____|_____|_____
#       |     |
#    4  |  5  |  6
#  _____|_____|_____
#       |     |
#    7  |  8  |  9
#       |     |
#
# choose your index  4
#
#       |     |
#    x  |  2  |  o
#  _____|_____|_____
#       |     |
#    x  |  5  |  6
#  _____|_____|_____
#       |     |
#    o  |  8  |  9
#       |     |
#
# choose your index  5
#
#       |     |
#    x  |  2  |  o
#  _____|_____|_____
#       |     |
#    x  |  x  |  6
#  _____|_____|_____
#       |     |
#    o  |  o  |  9
#       |     |
#
# choose your index  9
# winner

# %%
# mode %(3)%
# human vs intel pc
import random
m = list(range(1,10))
n = list(range(1,10))
y = input("enter your symbol  ")
for i in range(5):

    vertical = horizontal = rando = True
    check = False

    # to prevent overwriting 
    while True :
        x = int(input("enter your index  "))
        if x == m[x-1] :
            m[x-1] = y
            break
        else :
            print("wrong index please try again")
            table()        
            
    check = False
    for k in range(7):
        if k % 3 == 0 and m[k] == m[k+1] == m [k+2] :
            print("winner")
            check = True
            break
        elif k in range(3) and m[k]==m[k+3]==m[k+6] :
            print("winner")
            check = True
            break
        elif k==0 and m[k]==m[k+4]==m[k+8] :
            print("winner")
            check = True
            break
        elif k==3 and m[k]==m[k+2]==m[k+4] :
            print("winner")
            check = True
            break
    if check :
        break       
            
        
    # first move counter :-
    for k in range(9):
        if m[k] == "x" and i == 0:
            # sides game
            if m.index(m[k]) % 2 != 0 :
                m[random.choice([0,2,4,6,8])] = "o"
            # middle game 
            elif m.index(m[k]) == 4 :
                m[random.choice([0,2,6,8])] = "o"
            # corners game
            elif m.index(m[k]) % 2 == 0 and k != 4 :
                m[4] = "o"
                
                
    # two in a row counter / completer :-
    for e in range(7) :
        # to check rows
        if horizontal :
            for j in range(3) :
                if e % 3 == 0 and(m[e] == m[e+1] == "o" or m[e+1] == m[e+2] == "o" or m[e] == m[e+2] == "o")and m[e+j] == n[e+j] :
                    m[e+j] = "o"
                    vertical = horizontal = rando = False
                    break

                elif e % 3 == 0 and(m[e] == m[e+1] == "x" or m[e+1] == m[e+2] == "x" or m[e] == m[e+2] == "x")and m[e+j] == n[e+j] :
                    m[e+j] = "o"
                    vertical = horizontal = rando = False
                    break


        # to check columns 
        if vertical : 
            for j in range(0,7,3) :
                if e in range(3) and(m[e] == m[e+3] == "o" or m[e+3] == m[e+6] == "o" or m[e] == m[e+6] == "o")and m[e+j] == n[e+j] :
                    m[e+j] = "o"
                    vertical = horizontal = rando = False
                    break

                elif e in range(3) and(m[e] == m[e+3] == "x" or m[e+3] == m[e+6] == "x" or m[e] == m[e+6] == "x")and m[e+j] == n[e+j] :
                    m[e+j] = "o"
                    vertical = horizontal = rando = False
                    break


        # to choose randomly in case non of the above true
        if rando and i > 0:
            while True :
                v = random.choice(n)
                if v == m[v-1] :
                    m[v-1] = "o"
                    vertical = horizontal = random = False
                    break    

    # to check winning cases
        check = False
    for k in range(7):
        if k % 3 == 0 and m[k] == m[k+1] == m [k+2] :
            print("winner")
            check = True
            break
        elif k in range(3) and m[k]==m[k+3]==m[k+6] :
            print("winner")
            check = True
            break
        elif k==0 and m[k]==m[k+4]==m[k+8] :
            print("winner")
            check = True
            break
        elif k==3 and m[k]==m[k+2]==m[k+4] :
            print("winner")
            check = True
            break
    if check :
        break
    
    table()
# Out:
# enter your symbol  x
# enter your index  1
#
#       |     |
#    x  |  2  |  3
#  _____|_____|_____
#       |     |
#    4  |  o  |  6
#  _____|_____|_____
#       |     |
#    7  |  8  |  9
#       |     |
#
# enter your index  7
#
#       |     |
#    x  |  2  |  3
#  _____|_____|_____
#       |     |
#    o  |  o  |  6
#  _____|_____|_____
#       |     |
#    x  |  8  |  9
#       |     |
#
# enter your index  9
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f7d9a2de5436> in <module>
#      68         if rando and i > 0:
#      69             while True :
# ---> 70                 v = random.choice(n)
#      71                 if v == m[v-1] :
#      72                     m[v-1] = "o"
#
# AttributeError: 'bool' object has no attribute 'choice'
